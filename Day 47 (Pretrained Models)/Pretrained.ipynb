# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
img_path = '/content/tamato.jpg'
img = image.load_img(img_path,target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Predicted: [('n12620546', 'hip', np.float32(0.3137785)), ('n07745940', 'strawberry', np.float32(0.12847881)), ('n07720875', 'bell_pepper', np.float32(0.120377176))]

# %%
img_path = '/content/cat.18.jpg'
img = image.load_img(img_path,target_size=(224,224))
y = image.img_to_array(img)
y = np.expand_dims(y, axis=0)
y = preprocess_input(y)

# %%
preds = model.predict(y)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# Predicted: [('n02123045', 'tabby', np.float32(0.18774511)), ('n02124075', 'Egyptian_cat', np.float32(0.09921926)), ('n04525038', 'velvet', np.float32(0.06745639))]

# %%
img_path = '/content/dog.100.jpg'
img = image.load_img(img_path,target_size=(224,224))
l = image.img_to_array(img)
l = np.expand_dims(l, axis=0)
l = preprocess_input(l)

# %%
preds = model.predict(l)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# Predicted: [('n02087394', 'Rhodesian_ridgeback', np.float32(0.65184015)), ('n02093991', 'Irish_terrier', np.float32(0.18409894)), ('n02090379', 'redbone', np.float32(0.104550056))]

# %%
img_path = '/content/chair.jpg'
img = image.load_img(img_path,target_size=(224,224))
t = image.img_to_array(img)
t = np.expand_dims(t, axis=0)
t = preprocess_input(t)

# %%
preds = model.predict(t)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# Predicted: [('n03376595', 'folding_chair', np.float32(0.46628577)), ('n03201208', 'dining_table', np.float32(0.3534874)), ('n03179701', 'desk', np.float32(0.041877963))]
